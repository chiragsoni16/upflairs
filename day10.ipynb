# %%
import cv2
import skimage as ski
import matplotlib.pyplot as plt

# %%
img  = cv2.imread('Screenshot.png')
cv2.imshow('',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img1 = plt.imread('Screenshot.png')
plt.imshow(img1)
